# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
from scipy.stats import linregress

# %% [markdown]
# # Constants etc.
#
# This is the stuff we adapt according to our files and what we want for our plots

# %%
# CONSTANTS
tau_c = 0.2 # response time desired after applying PID

# FILES
files = ['Log_dt20_2.txt', 'Log_pid_dt20_2.txt']
names = ['sem PID', 'com PID'] # labels for the dictionary
PID_bol = [0, 1] # 1 if PID is already applied, 0 otherwhise

# PATHS
data_dir = Path('Dados')
im_dir = Path('../Imagens')
im_dir.mkdir(parents = True, exist_ok = True)

# PRETTY COLORS
plot_colors = ['mediumpurple', 'xkcd:dodger blue', 'yellowgreen', 'orange', 'xkcd:dull red'] # add more colors if more data
grid_color = 'lightgray'

# %% [markdown]
# # Load data

# %%
data = {} # dictionary to store data

for i, f in enumerate(files):
    d = np.loadtxt(data_dir / f).T # import data
    data[names[i]] = d # store in dictionary
    num = len(d[0]) # check size (must be 400)
    print(num)

    t = d[0]
    u1 = d[1]
    u2 = d[2]
    w1 = d[3]
    w2 = d[4]

    # check voltage is correct
    fig_u, ax_u = plt.subplots(figsize = (6, 4.5))
    ax_u.plot(t, u1, color = plot_colors[0] , label = f'Roda 1 - {names[i]}')
    ax_u.plot(t, u2, color = plot_colors[1] , label = f'Roda 2 - {names[i]}')
    ax_u.grid(color = grid_color)
    ax_u.set_xlabel('t (s)')
    ax_u.set_ylabel('V (V)')
    ax_u.legend()
    # fig_u.show()
# Out:
# 400
# 400
